# %%
# import modules 
import geopandas as gdp 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
X.columns
# Out:
# Index(['COUNTRY', 'NUTS2', 'NUTS3', 'CODE', 'CODE_NUTS2', 'CODE_NUTS3',
#        'POPULATION', 'POP_DENS', 'POP>=60', '%POP>=60', 'FEMEALES', '%FEMEALS',
#        'POP 0-14', 'POP 15-29', 'POP 30-44', 'POP 45-59', 'POP_GROWTH',
#        'HOUSEHOLDS', 'DWELLINGS', 'SURFACE AREA', 'UNEM_R', 'D_MEDICALE',
#        'COPD %', 'Respiratory dis mortality', 'Smokers %', 'Diabetes %',
#        'Diabetes mortality', 'Cardiovascular dis mortality',
#        'BEDS_Intcare/reanim', 'COVID19_D', 'COVID_Mortality_R',
#        'COVID19_CCONF', 'COVID_Cases_R', 'COVID19_TESTS', 'DURATION_LD (days)',
#        'Lag_1stCase-LD (days)', 'LD_SEVEIRTY_W1', 'LD_SEVEIRTY_W2',
#        'LD_SEVEIRTY_W3', 'LD_SEVEIRTY_W4', 'LD_SEVEIRTY_W5', 'LD_SEVEIRTY_W6',
#        'LD_SEVEIRTY_W7', 'LD_SEVEIRTY_W8', 'LD_SEVEIRTY_W9', 'LD_SEVEIRTY_W10',
#        'LD_SEVEIRTY_W11', 'LD_SEVEIRTY_W12', 'LD_SEVEIRTY_W13',
#        'LD_SEVEIRTY_W14', 'LD_SEVEIRTY_W15', 'LD_SEVEIRTY_W16',
# ...

# %%
# read data 
X = pd.read_excel('Input/Xis.xlsx', sheet_name = 'Data').drop(['COVID19_CCONF', 'COVID_Cases_R', 'COVID19_TESTS'], axis = 1)
X
# Out:
#              COUNTRY             NUTS2                     NUTS3 CODE  \
# 0            Austria                 -                         -   AT
# 1            Austria        Burgenland                         -   AT
# 2            Austria        Burgenland          Mittelburgenland   AT
# 3            Austria        Burgenland            Nordburgenland   AT
# 4            Austria        Burgenland             Südburgenland   AT
# ...              ...               ...                       ...  ...
# 1466  United Kingdom  Northern Ireland  Causeway Coast and Glens   UK
# 1467  United Kingdom  Northern Ireland   Antrim and Newtownabbey   UK
# 1468  United Kingdom  Northern Ireland   Lisburn and Castlereagh   UK
# 1469  United Kingdom  Northern Ireland       Mid and East Antrim   UK
# 1470  United Kingdom  Northern Ireland       Fermanagh and Omagh   UK
#
#      CODE_NUTS2 CODE_NUTS3  POPULATION  POP_DENS    POP>=60   %POP>=60  ...  \
# ...
