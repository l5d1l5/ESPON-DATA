# %%
# read modules 

import pandas as pd

# %%
# read the the dataset 
ds = pd.read_excel('../../02_Data/03_Explanatory varibales/Output/Xis.xlsx')
ds
# Out:
#                NUTS_ID  POPULATION_2019  POP_DENS_2019  POP>=60_2019  \
# 0                BG423              NaN            NaN           NaN
# 1                BG424              NaN            NaN           NaN
# 2                BG425              NaN            NaN           NaN
# 3                CH011         802965.0          276.0      172276.0
# 4                CH012         345051.0           66.0       87492.0
# ...                ...              ...            ...           ...
# 4702  Viana do Castelo              NaN            NaN           NaN
# 4703         Vila Real              NaN            NaN           NaN
# 4704             Viseu              NaN            NaN           NaN
# 4705             Évora              NaN            NaN           NaN
# 4706               UK_              NaN            NaN           NaN
#
#       %POP>=60_2019  FEMEALES_2018  %FEMEALS_2019  POP 0-14_2019  \
# 0               NaN            NaN            NaN            NaN
# ...

# %% [markdown]
# # 1. Data curation

# %% [markdown]
# # 2. Spatial economotrics models

# %% [markdown]
# ## 1.1 Ordinary Least Squares (OLS)

# %% [markdown]
# ## 1.2 Spatial Autoregressive model (SAR)

# %% [markdown]
# ## 1.3 Spatial Error Model (SEM)

# %% [markdown]
# ## 1.4 Spatial Autoregressive Confused (SAC)

# %%
#
