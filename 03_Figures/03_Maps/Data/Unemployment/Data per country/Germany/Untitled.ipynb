# %%
import pandas as pd

# %%
ref = pd.read_excel('Referenz Gemeinden-GVB-Kreise_NUTS.xlsx', skiprows = 1)
ref['Gemeinden 31.12.2017'] = ref['Gemeinden 31.12.2017'].apply(lambda x: str(x)[:-3])
ref.head(3)
# Out:
#   Gemeinden 31.12.2017              Unnamed: 1  \
# 0                 1001        Flensburg, Stadt
# 1                 1002  Kiel, Landeshauptstadt
# 2                 1003      Lübeck, Hansestadt
#
#    Zentralörtliche Einstufung (ja/nein)     Unnamed: 3  \
# 0                                     1  Zentraler Ort
# 1                                     1  Zentraler Ort
# 2                                     1  Zentraler Ort
#
#    Zentralörltiche Einstufung (4er Kategorie)             Unnamed: 5  \
# 0                                           1  Oberzentrum und höher
# 1                                           1  Oberzentrum und höher
# 2                                           1  Oberzentrum und höher
#
#    Zentralörtliche Einstufung differenziert   Unnamed: 7  Fäche in km²  \
# 0                                        10  Oberzentrum         56.74
# 1                                        10  Oberzentrum        118.65
# ...

# %%
tar = pd.read_excel('All table.xlsx')[['NUTS_ID', 'NUTS_NAME']]
tar
# Out:
#     NUTS_ID                                       NUTS_NAME
# 0        DG                                     Deutschland
# 1        01                              Schleswig-Holstein
# 2     01001                     Flensburg, kreisfreie Stadt
# 3     01002        Kiel, Landeshauptstadt, kreisfreie Stadt
# 4     01003            Lübeck, Hansestadt, kreisfreie Stadt
# ..      ...                                             ...
# 533   16073                      Saalfeld-Rudolstadt, Kreis
# 534   16074                            Saale-Holzland-Kreis
# 535   16075                                Saale-Orla-Kreis
# 536   16076                                    Greiz, Kreis
# 537   16077                         Altenburger Land, Kreis
#
# [538 rows x 2 columns]
